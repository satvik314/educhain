# %% [markdown]
# ## Generate Lesson Plan using [Educhain](https://github.com/satvik314/educhain)

# %% [markdown]
# Explore the power of AI-driven education with Educhain! This notebook demonstrates how to create high-quality Lesson Plans from various topics using the Educhain package.
#
# Key Features:
# - Customize prompts according to your need
# - Export lesson plan to CSV, JSON, or PDF formats
# - Leverage advanced language models for lesson plan generation
#
# Perfect for educators, content creators, and e-learning developers looking to automate and enhance their lesson plan creation process. Dive in to revolutionize your approach to educational content generation!

# %%
# !pip install git+https://github.com/lunatic-7/educhain.git@main
# Out:
# Collecting git+https://github.com/lunatic-7/educhain.git@main
#   Cloning https://github.com/lunatic-7/educhain.git (to revision main) to /tmp/pip-req-build-3phwx_g8
#   Running command git clone --filter=blob:none --quiet https://github.com/lunatic-7/educhain.git /tmp/pip-req-build-3phwx_g8
#   Resolved https://github.com/lunatic-7/educhain.git to commit a06893962b395fc18f988da08087cc7cc62aa00a
#   Preparing metadata (setup.py) ... done
# Collecting langchain (from educhain==0.3.2)
#   Downloading langchain-0.3.4-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-community (from educhain==0.3.2)
#   Downloading langchain_community-0.3.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting langchain-openai (from educhain==0.3.2)
#   Downloading langchain_openai-0.2.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting openai (from educhain==0.3.2)
#   Downloading openai-1.52.0-py3-none-any.whl.metadata (24 kB)
# Collecting python-dotenv (from educhain==0.3.2)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from educhain==0.3.2) (2.2.2)
# Collecting reportlab (from educhain==0.3.2)
#   Downloading reportlab-4.2.5-py3-none-any.whl.metadata (1.5 kB)
# Collecting PyPDF2 (from educhain==0.3.2)
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from educhain==0.3.2) (4.12.3)
# Collecting youtube_transcript_api (from educhain==0.3.2)
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from educhain==0.3.2) (2.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from educhain==0.3.2) (2.32.3)
# Collecting chromadb (from educhain==0.3.2)
#   Downloading chromadb-0.5.15-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->educhain==0.3.2) (2.6)
# Collecting build>=1.0.3 (from chromadb->educhain==0.3.2)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb->educhain==0.3.2)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb->educhain==0.3.2)
#   Downloading fastapi-0.115.2-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->educhain==0.3.2)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb->educhain==0.3.2)
#   Downloading posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb->educhain==0.3.2)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (1.16.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->educhain==0.3.2)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb->educhain==0.3.2)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (1.16.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb->educhain==0.3.2)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (4.66.5)
# Collecting overrides>=7.3.1 (from chromadb->educhain==0.3.2)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb->educhain==0.3.2)
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb->educhain==0.3.2)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb->educhain==0.3.2)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb->educhain==0.3.2)
#   Downloading orjson-3.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.2 MB/s eta 0:00:00
# Collecting httpx>=0.27.0 (from chromadb->educhain==0.3.2)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->educhain==0.3.2) (13.9.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->educhain==0.3.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->educhain==0.3.2) (2.23.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->educhain==0.3.2) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->educhain==0.3.2) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->educhain==0.3.2) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.12 (from langchain->educhain==0.3.2)
#   Downloading langchain_core-0.3.12-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain->educhain==0.3.2)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->educhain==0.3.2)
#   Downloading langsmith-0.1.136-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->educhain==0.3.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->educhain==0.3.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->educhain==0.3.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->educhain==0.3.2) (2024.8.30)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community->educhain==0.3.2)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community->educhain==0.3.2)
#   Downloading pydantic_settings-2.6.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai->educhain==0.3.2)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->educhain==0.3.2) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->educhain==0.3.2) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai->educhain==0.3.2)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->educhain==0.3.2) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->educhain==0.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->educhain==0.3.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->educhain==0.3.2) (2024.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab->educhain==0.3.2) (10.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab->educhain==0.3.2) (5.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (1.15.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->educhain==0.3.2) (1.2.2)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb->educhain==0.3.2) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->educhain==0.3.2)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb->educhain==0.3.2) (2.0.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->educhain==0.3.2)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->educhain==0.3.2)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.41.0,>=0.37.2 (from fastapi>=0.95.2->chromadb->educhain==0.3.2)
#   Downloading starlette-0.40.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting httpcore==1.* (from httpx>=0.27.0->chromadb->educhain==0.3.2)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.27.0->chromadb->educhain==0.3.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->educhain==0.3.2) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->educhain==0.3.2) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->educhain==0.3.2) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->educhain==0.3.2) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->educhain==0.3.2) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->educhain==0.3.2)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.12->langchain->educhain==0.3.2)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain->educhain==0.3.2)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->educhain==0.3.2)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->educhain==0.3.2) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->educhain==0.3.2) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->educhain==0.3.2) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->educhain==0.3.2) (1.2.14)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->educhain==0.3.2) (75.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->educhain==0.3.2) (1.65.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb->educhain==0.3.2)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->educhain==0.3.2)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb->educhain==0.3.2)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb->educhain==0.3.2)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->educhain==0.3.2)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->educhain==0.3.2)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb->educhain==0.3.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb->educhain==0.3.2) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->educhain==0.3.2) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai->educhain==0.3.2) (2024.9.11)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb->educhain==0.3.2) (0.24.7)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb->educhain==0.3.2) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb->educhain==0.3.2) (1.5.4)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb->educhain==0.3.2)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb->educhain==0.3.2)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->educhain==0.3.2)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->educhain==0.3.2)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->educhain==0.3.2) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->educhain==0.3.2) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->educhain==0.3.2) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->educhain==0.3.2) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->educhain==0.3.2) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->educhain==0.3.2) (3.20.2)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain->educhain==0.3.2)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->educhain==0.3.2) (0.1.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->educhain==0.3.2)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain->educhain==0.3.2) (0.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->educhain==0.3.2)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb->educhain==0.3.2) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->educhain==0.3.2) (0.6.1)
# Downloading chromadb-0.5.15-py3-none-any.whl (607 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.0/607.0 kB 16.5 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.2 MB/s eta 0:00:00
# Downloading langchain-0.3.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.7 MB/s eta 0:00:00
# Downloading langchain_community-0.3.3-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.3 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 3.1 MB/s eta 0:00:00
# Downloading openai-1.52.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 22.6 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 16.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading reportlab-4.2.5-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.7 MB/s eta 0:00:00
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 17.3 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.115.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 5.7 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.8 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 22.0 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.6 MB/s eta 0:00:00
# Downloading langchain_core-0.3.12-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 28.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.136-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 20.0 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 77.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.2 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 9.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 3.8 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.0 MB/s eta 0:00:00
# Downloading orjson-3.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 10.1 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.9 MB/s eta 0:00:00
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 28.8 MB/s eta 0:00:00
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.0 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.3 MB/s eta 0:00:00
# Downloading starlette-0.40.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 69.3 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 24.8 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 8.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: educhain, pypika
#   Building wheel for educhain (setup.py) ... done
#   Created wheel for educhain: filename=educhain-0.3.2-py3-none-any.whl size=15554 sha256=e74e4c920f039bc10b192209570e0e6475fdedabff63b9e2c85d336796be5580
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hsgqweb3/wheels/cf/37/1a/d1708e678c8679ecce8ee35b17f42fc00df5e425b1ef60b913
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=30b5b35b539c522a66e732dbc9e57aec1a4c18835a766503662627daa1a93bea
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built educhain pypika
# Installing collected packages: pypika, monotonic, durationpy, websockets, uvloop, reportlab, python-dotenv, pyproject_hooks, PyPDF2, overrides, orjson, opentelemetry-util-http, opentelemetry-proto, mypy-extensions, mmh3, marshmallow, jsonpointer, jiter, importlib-metadata, humanfriendly, httptools, h11, chroma-hnswlib, bcrypt, backoff, asgiref, youtube_transcript_api, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, requests-toolbelt, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, jsonpatch, httpcore, coloredlogs, build, pydantic-settings, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, httpx, fastapi, dataclasses-json, opentelemetry-sdk, opentelemetry-instrumentation-asgi, openai, langsmith, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-core, langchain-text-splitters, langchain-openai, chromadb, langchain, langchain-community, educhain
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.16.0
#     Uninstalling opentelemetry-api-1.16.0:
#       Successfully uninstalled opentelemetry-api-1.16.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.37b0
#     Uninstalling opentelemetry-semantic-conventions-0.37b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.37b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.16.0
#     Uninstalling opentelemetry-sdk-1.16.0:
#       Successfully uninstalled opentelemetry-sdk-1.16.0
# Successfully installed PyPDF2-3.0.1 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.15 coloredlogs-15.0.1 dataclasses-json-0.6.7 durationpy-0.9 educhain-0.3.2 fastapi-0.115.2 h11-0.14.0 httpcore-1.0.6 httptools-0.6.4 httpx-0.27.2 humanfriendly-10.0 importlib-metadata-8.4.0 jiter-0.6.1 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-31.0.0 langchain-0.3.4 langchain-community-0.3.3 langchain-core-0.3.12 langchain-openai-0.2.3 langchain-text-splitters-0.3.0 langsmith-0.1.136 marshmallow-3.23.0 mmh3-5.0.1 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.19.2 openai-1.52.0 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 orjson-3.10.9 overrides-7.7.0 posthog-3.7.0 pydantic-settings-2.6.0 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 reportlab-4.2.5 requests-toolbelt-1.0.0 starlette-0.40.0 tiktoken-0.8.0 typing-inspect-0.9.0 uvicorn-0.32.0 uvloop-0.21.0 watchfiles-0.24.0 websockets-13.1 youtube_transcript_api-0.6.2

# %%
# Set up your OpenAI API key
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %% [markdown]
# ## Generate lesson plan

# %%
from educhain import Educhain

client = Educhain()

plan = client.content_engine.generate_lesson_plan(
    topic = "Newton's Law of Motion"
    )

plan.show()
# Out:
# Raw output from LLM:
# ```json
# {
#   "title": "Exploring Newton's Laws of Motion",
#   "subject": "Physics",
#   "learning_objectives": [
#     "Understand and describe Newton's three laws of motion.",
#     "Apply Newton's laws to solve real-world problems.",
#     "Analyze and evaluate the impact of motion on everyday life."
#   ],
#   "lesson_introduction": "Have you ever wondered why a soccer ball rolls further on a smooth surface than on a rough one? To grab our attention, let’s watch a short video demonstrating various objects in motion. How do forces influence their movement? Today, we’ll dive into Newton's Laws of Motion and discover their significance in our daily lives!",
#   "main_topics": [
#     {
#       "title": "Newton's First Law: The Law of Inertia",
#       "subtopics": [
#         {
#           "title": "Understanding Inertia",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Inertia is the tendency of an object to resist changes in its state of motion."
#             },
#             {
#               "type": "example",
#               "content": "A stationary book will not move unless a force acts upon it."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Can you think of an example in real life where you observe inertia?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Inertia Demonstration",
#               "description": "Use a toy car to demonstrate inertia by rolling it on different surfaces."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "Why is understanding inertia important in designing vehicles?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "quiz",
#               "description": "A short quiz on identifying examples of inertia in everyday life."
#             }
#           ]
#         },
#         {
#           "title": "Applications of Inertia",
#           "key_concepts": [
#             {
#               "type": "example",
#               "content": "Seatbelts in cars are designed to counteract inertia."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How do seatbelts relate to Newton's First Law?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Seatbelt Safety Experiment",
#               "description": "Create a simple crash test using a toy car and a barrier to see the effects of inertia."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "What would happen in a car crash without seatbelts?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Create a visual presentation on the importance of seatbelt use."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Second Law: The Law of Acceleration",
#       "subtopics": [
#         {
#           "title": "Force, Mass, and Acceleration",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Newton's Second Law states that Force equals mass times acceleration (F = ma)."
#             },
#             {
#               "type": "example",
#               "content": "Pushing a heavier box requires more force than pushing a lighter one."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How can we apply this law to sports?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Force and Mass Experiment",
#               "description": "Use a spring scale to measure the force required to move objects of different masses."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does this law explain the motion of a rocket?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "written task",
#               "description": "Write a short essay explaining how Newton's Second Law applies to a sport."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Third Law: Action and Reaction",
#       "subtopics": [
#         {
#           "title": "Understanding Action and Reaction",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "For every action, there is an equal and opposite reaction."
#             },
#             {
#               "type": "example",
#               "content": "When you jump off a small boat, the boat moves in the opposite direction."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Can you think of other examples where this law applies?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Balloon Rocket Experiment",
#               "description": "Create a balloon rocket to demonstrate action and reaction using a string and a balloon."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does this law explain how airplanes fly?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Design a poster showing various examples of action and reaction in nature."
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "learning_adaptations": "Differentiate instruction by providing visual aids, hands-on demonstrations, and collaborative group work for varied learning styles.",
#   "real_world_applications": "Understanding Newton's laws is essential for engineers, athletes, and scientists. Careers such as aerospace engineering, automotive design, and physics research all rely on these principles.",
#   "ethical_considerations": "Discuss the importance of safety regulations in transportation and how understanding motion can lead to safer designs."
# }
# ```
# ================================================================================
# Lesson Plan: Exploring Newton's Laws of Motion
# Subject: Physics
# Learning Objectives: Understand and describe Newton's three laws of motion., Apply Newton's laws to solve real-world problems., Analyze and evaluate the impact of motion on everyday life.
# Lesson Introduction: Have you ever wondered why a soccer ball rolls further on a smooth surface than on a rough one? To grab our attention, let’s watch a short video demonstrating various objects in motion. How do forces influence their movement? Today, we’ll dive into Newton's Laws of Motion and discover their significance in our daily lives!
# ================================================================================
#
# Main Topic 1: Newton's First Law: The Law of Inertia
#
#    Subtopic 1.1: Understanding Inertia
#    Key Concepts:
#       - Definition: Inertia is the tendency of an object to resist changes in its state of motion.
#       - Example: A stationary book will not move unless a force acts upon it.
#    Discussion Questions:
#       - Can you think of an example in real life where you observe inertia?
#    Hands-On Activities:
#       - Inertia Demonstration: Use a toy car to demonstrate inertia by rolling it on different surfaces.
#    Reflective Questions:
#       - Why is understanding inertia important in designing vehicles?
#    Assessment Ideas:
#       - Quiz: A short quiz on identifying examples of inertia in everyday life.
#
#    Subtopic 1.2: Applications of Inertia
#    Key Concepts:
#       - Example: Seatbelts in cars are designed to counteract inertia.
#    Discussion Questions:
#       - How do seatbelts relate to Newton's First Law?
#    Hands-On Activities:
#       - Seatbelt Safety Experiment: Create a simple crash test using a toy car and a barrier to see the effects of inertia.
#    Reflective Questions:
#       - What would happen in a car crash without seatbelts?
#    Assessment Ideas:
#       - Project: Create a visual presentation on the importance of seatbelt use.
#
# Main Topic 2: Newton's Second Law: The Law of Acceleration
#
#    Subtopic 2.1: Force, Mass, and Acceleration
#    Key Concepts:
#       - Definition: Newton's Second Law states that Force equals mass times acceleration (F = ma).
#       - Example: Pushing a heavier box requires more force than pushing a lighter one.
#    Discussion Questions:
#       - How can we apply this law to sports?
#    Hands-On Activities:
#       - Force and Mass Experiment: Use a spring scale to measure the force required to move objects of different masses.
#    Reflective Questions:
#       - How does this law explain the motion of a rocket?
#    Assessment Ideas:
#       - Written task: Write a short essay explaining how Newton's Second Law applies to a sport.
#
# Main Topic 3: Newton's Third Law: Action and Reaction
#
#    Subtopic 3.1: Understanding Action and Reaction
#    Key Concepts:
#       - Definition: For every action, there is an equal and opposite reaction.
#       - Example: When you jump off a small boat, the boat moves in the opposite direction.
#    Discussion Questions:
#       - Can you think of other examples where this law applies?
#    Hands-On Activities:
#       - Balloon Rocket Experiment: Create a balloon rocket to demonstrate action and reaction using a string and a balloon.
#    Reflective Questions:
#       - How does this law explain how airplanes fly?
#    Assessment Ideas:
#       - Project: Design a poster showing various examples of action and reaction in nature.
#
# Learning Adaptations:  Differentiate instruction by providing visual aids, hands-on demonstrations, and collaborative group work for varied learning styles.
# Real-World Applications:  Understanding Newton's laws is essential for engineers, athletes, and scientists. Careers such as aerospace engineering, automotive design, and physics research all rely on these principles.
# Ethical Considerations:  Discuss the importance of safety regulations in transportation and how understanding motion can lead to safer designs.

# %% [markdown]
# ## Generate Lesson Plan with **custom instructions**

# %%
from educhain import Educhain

client = Educhain()

plan = client.content_engine.generate_lesson_plan(
    topic = "Newton's Law of Motion",
    custom_instructions = "Focus on hands-on activities and real-world examples."
)

plan.show()
# Out:
# Raw output from LLM:
# ```json
# {
#   "title": "Exploring Newton's Laws of Motion",
#   "subject": "Physics",
#   "learning_objectives": [
#     "Students will be able to state and explain Newton's three laws of motion.",
#     "Students will demonstrate understanding of the laws through real-world applications.",
#     "Students will apply Newton's laws in hands-on experiments to observe motion."
#   ],
#   "lesson_introduction": "To kick off our exploration of motion, imagine you're in a car that suddenly accelerates. What happens to your body? This real-world scenario highlights Newton's Laws of Motion. Today, we will uncover how these laws govern not only vehicles but also everything moving around us. What do you think would happen if there were no friction? Let’s find out!",
#   "main_topics": [
#     {
#       "title": "Newton's First Law of Motion",
#       "subtopics": [
#         {
#           "title": "Inertia",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Inertia is the tendency of an object to resist a change in its state of motion."
#             },
#             {
#               "type": "example",
#               "content": "A stationary ball will stay stationary until someone kicks it."
#             },
#             {
#               "type": "illustration",
#               "content": "Visual representation of an object at rest and in motion."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Can you think of a time when you felt the effects of inertia?"
#             },
#             {
#               "question": "How does inertia affect the safety features in cars?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Inertia Experiment",
#               "description": "Students will use a toy car and various surfaces to observe how inertia affects motion."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does understanding inertia help us in everyday life?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "quiz",
#               "description": "A short quiz on the definition of inertia and examples."
#             }
#           ]
#         },
#         {
#           "title": "Applications of First Law",
#           "key_concepts": [
#             {
#               "type": "example",
#               "content": "Seatbelts help to counteract inertia during a sudden stop."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Why do we need to wear seatbelts?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Seatbelt Safety Test",
#               "description": "Using a toy car and a ramp, students will simulate a crash to observe inertia."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "What did you learn about safety from this activity?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Create a poster demonstrating the first law with real-world examples."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Second Law of Motion",
#       "subtopics": [
#         {
#           "title": "Force, Mass, and Acceleration",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "The second law states that Force equals Mass times Acceleration (F=ma)."
#             },
#             {
#               "type": "example",
#               "content": "Pushing a car requires more force than pushing a bicycle."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How can we increase the acceleration of an object?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Force and Mass Experiment",
#               "description": "Students will use weights and a spring scale to measure the force needed to move objects of different masses."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "What did you notice about the relationship between mass and acceleration?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "written task",
#               "description": "Write a paragraph explaining how the second law applies to sports."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Third Law of Motion",
#       "subtopics": [
#         {
#           "title": "Action and Reaction",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "For every action, there is an equal and opposite reaction."
#             },
#             {
#               "type": "example",
#               "content": "When you jump off a small boat, the boat moves backward."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Can you think of other examples of action and reaction?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Balloon Rocket Experiment",
#               "description": "Students will create balloon rockets to observe action and reaction forces."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does understanding this law help us in our daily activities?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Design an experiment demonstrating Newton's Third Law."
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "learning_adaptations": "For younger students, simplify concepts using visuals and physical models. For advanced learners, challenge them to derive equations related to the laws of motion.",
#   "real_world_applications": "Understanding Newton's laws is essential for careers in engineering, physics, and aerospace. These principles are foundational in designing transportation systems, safety equipment, and athletic performance analysis.",
#   "ethical_considerations": "Discussing the societal impact of motion laws can lead to conversations about vehicle safety regulations and environmental considerations in transportation."
# }
# ```
# ================================================================================
# Lesson Plan: Exploring Newton's Laws of Motion
# Subject: Physics
# Learning Objectives: Students will be able to state and explain Newton's three laws of motion., Students will demonstrate understanding of the laws through real-world applications., Students will apply Newton's laws in hands-on experiments to observe motion.
# Lesson Introduction: To kick off our exploration of motion, imagine you're in a car that suddenly accelerates. What happens to your body? This real-world scenario highlights Newton's Laws of Motion. Today, we will uncover how these laws govern not only vehicles but also everything moving around us. What do you think would happen if there were no friction? Let’s find out!
# ================================================================================
#
# Main Topic 1: Newton's First Law of Motion
#
#    Subtopic 1.1: Inertia
#    Key Concepts:
#       - Definition: Inertia is the tendency of an object to resist a change in its state of motion.
#       - Example: A stationary ball will stay stationary until someone kicks it.
#       - Illustration: Visual representation of an object at rest and in motion.
#    Discussion Questions:
#       - Can you think of a time when you felt the effects of inertia?
#       - How does inertia affect the safety features in cars?
#    Hands-On Activities:
#       - Inertia Experiment: Students will use a toy car and various surfaces to observe how inertia affects motion.
#    Reflective Questions:
#       - How does understanding inertia help us in everyday life?
#    Assessment Ideas:
#       - Quiz: A short quiz on the definition of inertia and examples.
#
#    Subtopic 1.2: Applications of First Law
#    Key Concepts:
#       - Example: Seatbelts help to counteract inertia during a sudden stop.
#    Discussion Questions:
#       - Why do we need to wear seatbelts?
#    Hands-On Activities:
#       - Seatbelt Safety Test: Using a toy car and a ramp, students will simulate a crash to observe inertia.
#    Reflective Questions:
#       - What did you learn about safety from this activity?
#    Assessment Ideas:
#       - Project: Create a poster demonstrating the first law with real-world examples.
#
# Main Topic 2: Newton's Second Law of Motion
#
#    Subtopic 2.1: Force, Mass, and Acceleration
#    Key Concepts:
#       - Definition: The second law states that Force equals Mass times Acceleration (F=ma).
#       - Example: Pushing a car requires more force than pushing a bicycle.
#    Discussion Questions:
#       - How can we increase the acceleration of an object?
#    Hands-On Activities:
#       - Force and Mass Experiment: Students will use weights and a spring scale to measure the force needed to move objects of different masses.
#    Reflective Questions:
#       - What did you notice about the relationship between mass and acceleration?
#    Assessment Ideas:
#       - Written task: Write a paragraph explaining how the second law applies to sports.
#
# Main Topic 3: Newton's Third Law of Motion
#
#    Subtopic 3.1: Action and Reaction
#    Key Concepts:
#       - Definition: For every action, there is an equal and opposite reaction.
#       - Example: When you jump off a small boat, the boat moves backward.
#    Discussion Questions:
#       - Can you think of other examples of action and reaction?
#    Hands-On Activities:
#       - Balloon Rocket Experiment: Students will create balloon rockets to observe action and reaction forces.
#    Reflective Questions:
#       - How does understanding this law help us in our daily activities?
#    Assessment Ideas:
#       - Project: Design an experiment demonstrating Newton's Third Law.
#
# Learning Adaptations:  For younger students, simplify concepts using visuals and physical models. For advanced learners, challenge them to derive equations related to the laws of motion.
# Real-World Applications:  Understanding Newton's laws is essential for careers in engineering, physics, and aerospace. These principles are foundational in designing transportation systems, safety equipment, and athletic performance analysis.
# Ethical Considerations:  Discussing the societal impact of motion laws can lead to conversations about vehicle safety regulations and environmental considerations in transportation.

# %% [markdown]
# ## Generate Lesson Plan using different models (eg: Gemini)

# %%
# !pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from langchain_google_genai) (0.8.3)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain_google_genai) (0.3.12)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_google_genai) (2.9.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.66.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.24.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_google_genai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_google_genai) (0.1.136)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_google_genai) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_google_genai) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain_google_genai) (2.23.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain_google_genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (3.10.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (1.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (3.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_google_genai) (1.2.2)
# Downloading langchain_google_genai-2.0.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: langchain_google_genai
# Successfully installed langchain_google_genai-2.0.1

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from educhain import Educhain, LLMConfig

gemini_flash = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash-exp-0827",
    google_api_key=userdata.get("GOOGLE_API_KEY"))

flash_config = LLMConfig(custom_model=gemini_flash)
client = Educhain(flash_config) #using gemini model with educhain

plan = client.content_engine.generate_lesson_plan(
    topic = "Newton's Law of Motion"
)

plan.show()
# Out:
# Raw output from LLM:
# ```json
# {
#   "title": "Newton's Laws of Motion: Understanding the Forces Around Us",
#   "subject": "Physics/Science",
#   "learning_objectives": [
#     "Students will be able to define Newton's three laws of motion and provide examples of each.",
#     "Students will be able to apply Newton's laws to solve basic problems involving force, mass, and acceleration.",
#     "Students will be able to analyze real-world scenarios and identify the forces at play using Newton's laws.",
#     "Students will be able to evaluate the impact of Newton's laws on various technological advancements."
#   ],
#   "lesson_introduction": "Have you ever wondered why a ball thrown upwards eventually falls back down? Or how a rocket propels itself into space? These phenomena are all explained by a set of fundamental principles known as Newton's Laws of Motion. These laws govern the motion of everything around us, from the smallest particles to the largest celestial bodies.  In this lesson, we will explore these laws and discover how they shape our understanding of the universe.",
#   "main_topics": [
#     {
#       "title": "Newton's First Law of Motion: Inertia",
#       "subtopics": [
#         {
#           "title": "Understanding Inertia",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Inertia is the tendency of an object to resist changes in its state of motion. An object at rest will stay at rest, and an object in motion will stay in motion with the same speed and direction unless acted upon by an unbalanced force."
#             },
#             {
#               "type": "example",
#               "content": "A book resting on a table will remain there until someone pushes or pulls it. A car moving at a constant speed will continue moving at that speed until the brakes are applied."
#             },
#             {
#               "type": "illustration",
#               "content": "Show a visual of a book on a table and a car moving at constant speed, then show the external forces acting on them (push, brake)."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Why do you feel a force pushing you back when a car accelerates?"
#             },
#             {
#               "question": "How does the mass of an object affect its inertia?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Inertia Challenge",
#               "description": "Students will participate in a series of activities demonstrating inertia, like pulling a tablecloth from under a set of dishes or trying to quickly stop a moving toy car."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does the concept of inertia explain why seatbelts are important in cars?"
#             },
#             {
#               "question": "Can you think of other examples of inertia in everyday life?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "quiz",
#               "description": "A short quiz on definitions and examples related to inertia."
#             }
#           ]
#         },
#         {
#           "title": "Balanced and Unbalanced Forces",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Balanced forces are forces that cancel each other out, resulting in no change in motion. Unbalanced forces cause a change in an object's motion (either starting, stopping, or changing direction/speed)."
#             },
#             {
#               "type": "example",
#               "content": "Two people pushing a box with equal force in opposite directions (balanced). One person pushing a box (unbalanced)."
#             },
#             {
#               "type": "multimedia",
#               "content": "Use a simulation or video to demonstrate the effects of balanced and unbalanced forces on an object's motion."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "What happens to an object when the forces acting on it are balanced?"
#             },
#             {
#               "question": "How can you tell if a force is balanced or unbalanced?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Force and Motion Simulation",
#               "description": "Students will use a physics simulation software to explore how different forces affect the motion of an object, observing the effects of balanced and unbalanced forces."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does the concept of balanced and unbalanced forces relate to Newton's First Law?"
#             },
#             {
#               "question": "Can you think of a real-world example where understanding balanced and unbalanced forces is crucial?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "written task",
#               "description": "Students will describe a scenario with balanced and unbalanced forces and explain the resulting motion."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Second Law of Motion: Force, Mass, and Acceleration",
#       "subtopics": [
#         {
#           "title": "The Relationship Between Force, Mass, and Acceleration",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Newton's Second Law states that the acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass.  (F = ma)"
#             },
#             {
#               "type": "example",
#               "content": "Pushing a heavier object requires more force to achieve the same acceleration as a lighter object."
#             },
#             {
#               "type": "illustration",
#               "content": "Visualize a graph showing the relationship between force, mass, and acceleration."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How does the mass of an object affect its acceleration when a constant force is applied?"
#             },
#             {
#               "question": "If you double the force acting on an object, what happens to its acceleration?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Force and Acceleration Experiment",
#               "description": "Students will design and conduct an experiment to investigate how changing the force or mass of an object affects its acceleration using toy cars, ramps, and weights."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How can you use Newton's Second Law to explain the motion of a rocket?"
#             },
#             {
#               "question": "How does this law apply to sports, such as hitting a baseball or kicking a soccer ball?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Students will design a roller coaster and calculate the forces and accelerations involved at different points."
#             }
#           ]
#         },
#         {
#           "title": "Calculating Force, Mass, and Acceleration",
#           "key_concepts": [
#             {
#               "type": "example",
#               "content": "A 10 kg object is pushed with a force of 50 N. Calculate the acceleration of the object. (F=ma, so a = F/m = 50N/10kg = 5 m/s²)."
#             },
#             {
#               "type": "content",
#               "content": "Explain how to solve problems using the formula F=ma, emphasizing the importance of units."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How do the units of force, mass, and acceleration relate to each other?"
#             },
#             {
#               "question": "What are some common mistakes students make when applying the formula F=ma?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Force Problem-Solving Workshop",
#               "description": "Students will work in groups to solve a variety of word problems related to Newton's Second Law, using the formula F=ma."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How confident are you in your ability to apply the formula F=ma to solve problems?"
#             },
#             {
#               "question": "What are some challenges you faced when solving force problems?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "quiz",
#               "description": "A quiz with multiple-choice and short-answer questions focusing on applying the formula F=ma."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Newton's Third Law of Motion: Action and Reaction",
#       "subtopics": [
#         {
#           "title": "Understanding Action and Reaction Pairs",
#           "key_concepts": [
#             {
#               "type": "definition",
#               "content": "Newton's Third Law states that for every action, there is an equal and opposite reaction. When one object exerts a force on another object, the second object exerts an equal and opposite force back on the first."
#             },
#             {
#               "type": "example",
#               "content": "When you jump, you push down on the ground (action), and the ground pushes you up (reaction)."
#             },
#             {
#               "type": "illustration",
#               "content": "Show a visual of a person jumping, illustrating the action-reaction forces."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "Why do you feel a force pushing back on you when you push against a wall?"
#             },
#             {
#               "question": "How does the action-reaction force pair explain how a rocket launches?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Balloon Rocket Challenge",
#               "description": "Students will design and build balloon-powered rockets to demonstrate action-reaction forces. They will analyze how the force of the air escaping the balloon propels the rocket forward."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How does Newton's Third Law explain how a swimmer propels themselves through the water?"
#             },
#             {
#               "question": "Can you think of other examples where action-reaction forces are at play?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "written task",
#               "description": "Students will create a comic strip or storyboard illustrating several examples of action-reaction force pairs."
#             }
#           ]
#         },
#         {
#           "title": "Applications of Action-Reaction in Technology",
#           "key_concepts": [
#             {
#               "type": "content",
#               "content": "Discuss how Newton's Third Law is applied in various technologies like jet engines, rockets, and even walking."
#             },
#             {
#               "type": "multimedia",
#               "content": "Show videos or animations of different technologies that utilize action-reaction forces."
#             }
#           ],
#           "discussion_questions": [
#             {
#               "question": "How does a jet engine use Newton's Third Law to generate thrust?"
#             },
#             {
#               "question": "Can you think of other technologies that rely on action-reaction forces?"
#             }
#           ],
#           "hands_on_activities": [
#             {
#               "title": "Technology Design Challenge",
#               "description": "Students will work in teams to design a new technology that utilizes Newton's Third Law to solve a specific problem. They will present their designs and explain how the action-reaction forces are involved."
#             }
#           ],
#           "reflective_questions": [
#             {
#               "question": "How has the understanding of action-reaction forces impacted technological advancements?"
#             },
#             {
#               "question": "What are some potential future applications of Newton's Third Law?"
#             }
#           ],
#           "assessment_ideas": [
#             {
#               "type": "project",
#               "description": "Students will create a presentation or model demonstrating a real-world application of Newton's Third Law, explaining the action-reaction forces involved."
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "learning_adaptations": "For younger students (elementary/middle school), the focus can be on understanding the basic concepts of inertia, force, and motion through simple demonstrations and activities. The mathematical aspects of Newton's Second Law can be introduced gradually as students develop a stronger foundation in math and science. For older students (high school), the lesson can delve deeper into the mathematical applications of Newton's laws, including solving complex problems and exploring more advanced topics like momentum and impulse.",
#   "real_world_applications": "Understanding Newton's Laws of Motion is crucial in a variety of fields, including engineering, aerospace, sports, and transportation. Careers that rely on these principles include aerospace engineers, mechanical engineers, physicists, sports scientists, and automotive engineers. Further learning paths could involve studying advanced physics, engineering, or related fields.",
#   "ethical_considerations": "The application of Newton's Laws can have both positive and negative impacts on society. For example, advancements in transportation and technology have improved our lives, but they have also contributed to environmental challenges. It's important for students to consider the ethical implications of applying scientific principles and to strive for responsible innovation."
# }
# ```
# ================================================================================
# Lesson Plan: Newton's Laws of Motion: Understanding the Forces Around Us
# Subject: Physics/Science
# Learning Objectives: Students will be able to define Newton's three laws of motion and provide examples of each., Students will be able to apply Newton's laws to solve basic problems involving force, mass, and acceleration., Students will be able to analyze real-world scenarios and identify the forces at play using Newton's laws., Students will be able to evaluate the impact of Newton's laws on various technological advancements.
# Lesson Introduction: Have you ever wondered why a ball thrown upwards eventually falls back down? Or how a rocket propels itself into space? These phenomena are all explained by a set of fundamental principles known as Newton's Laws of Motion. These laws govern the motion of everything around us, from the smallest particles to the largest celestial bodies.  In this lesson, we will explore these laws and discover how they shape our understanding of the universe.
# ================================================================================
#
# Main Topic 1: Newton's First Law of Motion: Inertia
#
#    Subtopic 1.1: Understanding Inertia
#    Key Concepts:
#       - Definition: Inertia is the tendency of an object to resist changes in its state of motion. An object at rest will stay at rest, and an object in motion will stay in motion with the same speed and direction unless acted upon by an unbalanced force.
#       - Example: A book resting on a table will remain there until someone pushes or pulls it. A car moving at a constant speed will continue moving at that speed until the brakes are applied.
#       - Illustration: Show a visual of a book on a table and a car moving at constant speed, then show the external forces acting on them (push, brake).
#    Discussion Questions:
#       - Why do you feel a force pushing you back when a car accelerates?
#       - How does the mass of an object affect its inertia?
#    Hands-On Activities:
#       - Inertia Challenge: Students will participate in a series of activities demonstrating inertia, like pulling a tablecloth from under a set of dishes or trying to quickly stop a moving toy car.
#    Reflective Questions:
#       - How does the concept of inertia explain why seatbelts are important in cars?
#       - Can you think of other examples of inertia in everyday life?
#    Assessment Ideas:
#       - Quiz: A short quiz on definitions and examples related to inertia.
#
#    Subtopic 1.2: Balanced and Unbalanced Forces
#    Key Concepts:
#       - Definition: Balanced forces are forces that cancel each other out, resulting in no change in motion. Unbalanced forces cause a change in an object's motion (either starting, stopping, or changing direction/speed).
#       - Example: Two people pushing a box with equal force in opposite directions (balanced). One person pushing a box (unbalanced).
#       - Multimedia: Use a simulation or video to demonstrate the effects of balanced and unbalanced forces on an object's motion.
#    Discussion Questions:
#       - What happens to an object when the forces acting on it are balanced?
#       - How can you tell if a force is balanced or unbalanced?
#    Hands-On Activities:
#       - Force and Motion Simulation: Students will use a physics simulation software to explore how different forces affect the motion of an object, observing the effects of balanced and unbalanced forces.
#    Reflective Questions:
#       - How does the concept of balanced and unbalanced forces relate to Newton's First Law?
#       - Can you think of a real-world example where understanding balanced and unbalanced forces is crucial?
#    Assessment Ideas:
#       - Written task: Students will describe a scenario with balanced and unbalanced forces and explain the resulting motion.
#
# Main Topic 2: Newton's Second Law of Motion: Force, Mass, and Acceleration
#
#    Subtopic 2.1: The Relationship Between Force, Mass, and Acceleration
#    Key Concepts:
#       - Definition: Newton's Second Law states that the acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass.  (F = ma)
#       - Example: Pushing a heavier object requires more force to achieve the same acceleration as a lighter object.
#       - Illustration: Visualize a graph showing the relationship between force, mass, and acceleration.
#    Discussion Questions:
#       - How does the mass of an object affect its acceleration when a constant force is applied?
#       - If you double the force acting on an object, what happens to its acceleration?
#    Hands-On Activities:
#       - Force and Acceleration Experiment: Students will design and conduct an experiment to investigate how changing the force or mass of an object affects its acceleration using toy cars, ramps, and weights.
#    Reflective Questions:
#       - How can you use Newton's Second Law to explain the motion of a rocket?
#       - How does this law apply to sports, such as hitting a baseball or kicking a soccer ball?
#    Assessment Ideas:
#       - Project: Students will design a roller coaster and calculate the forces and accelerations involved at different points.
#
#    Subtopic 2.2: Calculating Force, Mass, and Acceleration
#    Key Concepts:
#       - Example: A 10 kg object is pushed with a force of 50 N. Calculate the acceleration of the object. (F=ma, so a = F/m = 50N/10kg = 5 m/s²).
#       - Content: Explain how to solve problems using the formula F=ma, emphasizing the importance of units.
#    Discussion Questions:
#       - How do the units of force, mass, and acceleration relate to each other?
#       - What are some common mistakes students make when applying the formula F=ma?
#    Hands-On Activities:
#       - Force Problem-Solving Workshop: Students will work in groups to solve a variety of word problems related to Newton's Second Law, using the formula F=ma.
#    Reflective Questions:
#       - How confident are you in your ability to apply the formula F=ma to solve problems?
#       - What are some challenges you faced when solving force problems?
#    Assessment Ideas:
#       - Quiz: A quiz with multiple-choice and short-answer questions focusing on applying the formula F=ma.
#
# Main Topic 3: Newton's Third Law of Motion: Action and Reaction
#
#    Subtopic 3.1: Understanding Action and Reaction Pairs
#    Key Concepts:
#       - Definition: Newton's Third Law states that for every action, there is an equal and opposite reaction. When one object exerts a force on another object, the second object exerts an equal and opposite force back on the first.
#       - Example: When you jump, you push down on the ground (action), and the ground pushes you up (reaction).
#       - Illustration: Show a visual of a person jumping, illustrating the action-reaction forces.
#    Discussion Questions:
#       - Why do you feel a force pushing back on you when you push against a wall?
#       - How does the action-reaction force pair explain how a rocket launches?
#    Hands-On Activities:
#       - Balloon Rocket Challenge: Students will design and build balloon-powered rockets to demonstrate action-reaction forces. They will analyze how the force of the air escaping the balloon propels the rocket forward.
#    Reflective Questions:
#       - How does Newton's Third Law explain how a swimmer propels themselves through the water?
#       - Can you think of other examples where action-reaction forces are at play?
#    Assessment Ideas:
#       - Written task: Students will create a comic strip or storyboard illustrating several examples of action-reaction force pairs.
#
#    Subtopic 3.2: Applications of Action-Reaction in Technology
#    Key Concepts:
#       - Content: Discuss how Newton's Third Law is applied in various technologies like jet engines, rockets, and even walking.
#       - Multimedia: Show videos or animations of different technologies that utilize action-reaction forces.
#    Discussion Questions:
#       - How does a jet engine use Newton's Third Law to generate thrust?
#       - Can you think of other technologies that rely on action-reaction forces?
#    Hands-On Activities:
#       - Technology Design Challenge: Students will work in teams to design a new technology that utilizes Newton's Third Law to solve a specific problem. They will present their designs and explain how the action-reaction forces are involved.
#    Reflective Questions:
#       - How has the understanding of action-reaction forces impacted technological advancements?
#       - What are some potential future applications of Newton's Third Law?
#    Assessment Ideas:
#       - Project: Students will create a presentation or model demonstrating a real-world application of Newton's Third Law, explaining the action-reaction forces involved.
#
# Learning Adaptations:  For younger students (elementary/middle school), the focus can be on understanding the basic concepts of inertia, force, and motion through simple demonstrations and activities. The mathematical aspects of Newton's Second Law can be introduced gradually as students develop a stronger foundation in math and science. For older students (high school), the lesson can delve deeper into the mathematical applications of Newton's laws, including solving complex problems and exploring more advanced topics like momentum and impulse.
# Real-World Applications:  Understanding Newton's Laws of Motion is crucial in a variety of fields, including engineering, aerospace, sports, and transportation. Careers that rely on these principles include aerospace engineers, mechanical engineers, physicists, sports scientists, and automotive engineers. Further learning paths could involve studying advanced physics, engineering, or related fields.
# Ethical Considerations:  The application of Newton's Laws can have both positive and negative impacts on society. For example, advancements in transportation and technology have improved our lives, but they have also contributed to environmental challenges. It's important for students to consider the ethical implications of applying scientific principles and to strive for responsible innovation.
